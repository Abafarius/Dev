# %%
import pandas as pd
data = pd.Series(list(range(10, 1001)))

# %%
print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])
# Out:
# -70

# %%
pd.Series(["Кот", "Собака", "Корова", "Лемур"], index = [3,7,12,26])
# Out:
# 3        Кот
# 7     Собака
# 12    Корова
# 26     Лемур
# dtype: object

# %%
pd.Series([3,7,12,26], index = ["Кот", "Собака", "Корова", "Лемур"])
# Out:
# Кот        3
# Собака     7
# Корова    12
# Лемур     26
# dtype: int64

# %%
import pandas as pd
df = pd.DataFrame({'Тестовая колонка': [1, 5]})
display(df)
# Out:
#    Тестовая колонка
# 0                 1
# 1                 5

# %%
df = pd.read_csv('data_sf.csv')
df
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# Name               object
# Age                 int64
# Nationality        object
# Club               object
# Value               int64
# Wage                int64
# Position           object
# Crossing            int64
# Finishing           int64
# HeadingAccuracy     int64
# ShortPassing        int64
# Volleys             int64
# Dribbling           int64
# Curve               int64
# FKAccuracy          int64
# LongPassing         int64
# BallControl         int64
# Acceleration        int64
# SprintSpeed         int64
# Agility             int64
# Reactions           int64
# Balance             int64
# ShotPower           int64
# Jumping             int64
# Stamina             int64
# Strength            int64
# LongShots           int64
# Aggression          int64
# Interceptions       int64
# Positioning         int64
# Vision              int64
# Penalties           int64
# Composure           int64
# Marking             int64
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
round(7.1)
# Out:
# 7

# %%
with pd.option_context('display.max_columns', None):
    display(df.describe())
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
round(24.795379)
# Out:
# 25

# %%
clubs = df.Club

# %%
clubs.unique
# Out:
# <bound method Series.unique of 0               FC Barcelona
# 1                   Juventus
# 2        Paris Saint-Germain
# 3          Manchester United
# 4            Manchester City
#                 ...
# 12892        Crewe Alexandra
# 12893         Trelleborgs FF
# 12894       Cambridge United
# 12895        Tranmere Rovers
# 12896        Tranmere Rovers
# Name: Club, Length: 12897, dtype: object>

# %%
df.describe(include = ['object'])
# Out:
#                 Name Nationality             Club Position
# count          12897       12897            12897    12897
# unique         12326         156              650       27
# top     J. Rodríguez     England  Shonan Bellmare       GK
# freq               9        1368               30     1641

# %%
wage = df.Wage

# %%
wage.median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0        565000
# 1        405000
# 2        290000
# 3        260000
# 4        355000
#           ...
# 12892      1000
# 12893      1000
# 12894      1000
# 12895      1000
# 12896      1000
# Name: Wage, Length: 12897, dtype: int64>

# %%
import statistics

# %%
statistics.median(wage)
# Out:
# 2000

# %%
wage.sum()
# Out:
# 96954000

# %%
Wage_over_mean = df[df.Wage > df.Wage.mean()]
Wage_over_mean['SprintSpeed'].mean()
# Out:
# 67.56638061585058

# %%
Wage_less_mean = df[df.Wage < df.Wage.mean()]
Wage_less_mean['SprintSpeed'].mean()
# Out:
# 62.41425430560645

# %%
with pd.option_context('display.max_columns', None):
    display(df.sort_values(by=['Wage'], ascending=False))
# Out:
#        Unnamed: 0               Name  Age Nationality              Club  \
# 0               0           L. Messi   31   Argentina      FC Barcelona
# 7               7          L. Suárez   31     Uruguay      FC Barcelona
# 6               6          L. Modrić   32     Croatia       Real Madrid
# 1               1  Cristiano Ronaldo   33    Portugal          Juventus
# 8               8       Sergio Ramos   32       Spain       Real Madrid
# ...           ...                ...  ...         ...               ...
# 4957         5112      N. Busch Thor   32      Sweden         IK Sirius
# 4960         5115           D. Ovono   35       Gabon          Paris FC
# 9248         9449          J. Albert   26      France  Clermont Foot 63
# 4966         5121         M. Pascali   36       Italy           Cosenza
# 12896       13125          G. Nugent   16     England   Tranmere Rovers
#
#            Value    Wage Position  Crossing  Finishing  HeadingAccuracy  \
# ...

# %%
Brasil_players = df[df.Nationality =='Brazil']
Brasil_players['Penalties'].sum()
# Out:
# 22789

# %%
HeadingAccuracy = df[df.HeadingAccuracy > 50]
HeadingAccuracy
with pd.option_context('display.max_columns', None):
    display(HeadingAccuracy)
# Out:
#        Unnamed: 0                Name  Age     Nationality  \
# 0               0            L. Messi   31       Argentina
# 1               1   Cristiano Ronaldo   33        Portugal
# 2               2           Neymar Jr   26          Brazil
# 4               4        K. De Bruyne   27         Belgium
# 5               5           E. Hazard   27         Belgium
# ...           ...                 ...  ...             ...
# 12769       12998         T. Kawamura   18           Japan
# 12777       13006         Kwon Ki Pyo   21  Korea Republic
# 12788       13017           S. Dawood   19    Saudi Arabia
# 12818       13047           Zhu Jiayi   19        China PR
# 12893       13122  N. Christoffersson   19          Sweden
#
#                       Club      Value    Wage Position  Crossing  Finishing  \
# 0             FC Barcelona  110500000  565000       RF        84         95
# 1                 Juventus   77000000  405000       ST        84         94
# ...

# %%
HeadingAccuracy['Age'].mean()
# Out:
# 25.58771113179944

# %%
Reactions = 96
Composure = 96
86,4
Reaction_and_Composure = df[df.Reactions & df.Composure > 86.4]
Reaction_and_Composure['Age'].min()
# Out:
# 24

# %%
Max_age = df[df.Age == df['Age'].max()]
Max_age
# Out:
#       Unnamed: 0      Name  Age Nationality     Club    Value  Wage Position  \
# 1628        1695  O. Pérez   45      Mexico  Pachuca  1300000  8000       GK
#
#       Crossing  Finishing  ...  Penalties  Composure  Marking  StandingTackle  \
# 1628        19         14  ...         23         62       23              12
#
#       SlidingTackle  GKDiving  GKHandling  GKKicking  GKPositioning  \
# 1628             11        70          64         65             73
#
#       GKReflexes
# 1628          74
#
# [1 rows x 42 columns]

# %%
Max_age['Reactions'].mean()
# Out:
# 72.0

# %%
Min_age = df[df.Age == df['Age'].min()]
Min_age
# Out:
#        Unnamed: 0             Name  Age          Nationality  \
# 6278         6449      W. Geubbels   16               France
# 6550         6724         A. Taoui   16               France
# 7306         7487   Pelayo Morilla   16                Spain
# 7632         7819         Guerrero   16                Spain
# 8046         8236      H. Massengo   16               France
# 8318         8509   Y. Verschaeren   16              Belgium
# 10094       10302        Y. Roemer   16          Netherlands
# 10471       10685      Y. Begraoui   16               France
# 10517       10732         J. Lahne   16               Sweden
# 10801       11020      J. Italiano   16            Australia
# 10971       11191        S. Steijn   16          Netherlands
# 11134       11355      J. Kitolano   16               Norway
# 11257       11479       D. Adshead   16              England
# 11637       11861        B. Nygren   16               Sweden
# ...

# %%
Min_age['Reactions'].mean()
# Out:
# 49.357142857142854

# %%
Max_age['Reactions'].mean() - Min_age['Reactions'].mean()
# Out:
# 22.642857142857146

# %%
Value_over_mean = df[df.Value > df['Value'].mean()]
Value_over_mean
# Out:
#        Unnamed: 0               Name  Age          Nationality  \
# 0               0           L. Messi   31            Argentina
# 1               1  Cristiano Ronaldo   33             Portugal
# 2               2          Neymar Jr   26               Brazil
# 3               3             De Gea   27                Spain
# 4               4       K. De Bruyne   27              Belgium
# ...           ...                ...  ...                  ...
# 12736       12965          J. Morris   18              England
# 12774       13003          J. Martin   19  Republic of Ireland
# 12812       13041            J. Egan   19              England
# 12857       13086             Wu Lei   21             China PR
# 12869       13098        J. Williams   17              England
#
#                       Club      Value    Wage Position  Crossing  Finishing  \
# 0             FC Barcelona  110500000  565000       RF        84         95
# ...

# %%
Value_over_mean.describe(include = ['object'])
# Out:
#                 Name Nationality             Club Position
# count           1747        1747             1747     1747
# unique          1558          98              447       27
# top     J. Rodríguez       Spain  Manchester City       ST
# freq               9         211               17      214

# %%
gk = df[df.Position == 'GK']
maxGKref = gk[gk.GKReflexes == gk['GKReflexes'].max()]
maxGKref['Wage'].mean()
# Out:
# 260000.0

# %%
maxGKHandl = gk[gk.GKHandling == gk['GKHandling'].max()]
maxGKHandl
maxGKHandl['Wage'].mean()
# Out:
# 94000.0

# %%
maxGKref['Wage'].mean() - maxGKHandl['Wage'].mean()
# Out:
# 166000.0

# %%
aggrmax = df[df.Aggression == df['Aggression'].max()]
aggr['ShotPower'].mean()
# Out:
# 63.0

# %%
aggrmin = df[df.Aggression == df['Aggression'].min()]
aggrmin['ShotPower'].mean()
# Out:
# 30.333333333333332

# %%
aggr['ShotPower'].mean() - aggrmin['ShotPower'].mean()
# Out:
# 32.66666666666667
